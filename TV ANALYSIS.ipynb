# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno

# %%
tv = pd.read_csv("TV_Final.xls")
tv
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
tv1 =tv.copy()

# %%
tv.Brand.value_counts()
# Out:
# SAMSUNG             140
# LG                  122
# SONY                 62
# TCL                  44
# Panasonic            30
# Micromax             25
# Vu                   23
# Lloyd                22
# Mi                   19
# iFFALCON by TCL      19
# Thomson              18
# Haier                18
# Sansui               18
# PHILIPS              17
# Blaupunkt            15
# KODAK                15
# MOTOROLA             15
# IMPEX                13
# TOSHIBA              13
# Croma                12
# Candes               12
# Onida                12
# Power Guard          11
# Nokia                11
# T-Series             11
# Hisense              10
# CloudWalker           9
# OnePlus               9
# RGL                   9
# Acer                  9
# Coocaa                9
# AISEN                 8
# MarQ by Flipkart      8
# Sharp                 8
# Onix                  8
# G-TEN                 8
# realme                7
# Adsun                 7
# ...

# %%
tv['Operating System'].unique()
# Out:
# array(['VIDAA', 'Android', 'Linux', nan, 'Tizen', 'WebOS', 'HomeOS',
#        'FireTV OS'], dtype=object)

# %%
tv.shape
# Out:
# (912, 7)

# %%
tv.describe()
# Out:
#             Size   Selling Price  Original Price      Rating
# count  912.000000     912.000000      912.000000  692.000000
# mean    45.942982   59358.606360    81975.213816    4.234104
# std     12.316492   65866.677856    84823.568826    0.366694
# min     17.000000    4849.000000     6999.000000    2.000000
# 25%     32.000000   19797.500000    28990.000000    4.100000
# 50%     43.000000   36990.000000    52900.000000    4.300000
# 75%     55.000000   67064.250000    99900.000000    4.400000
# max     85.000000  499990.000000   549990.000000    5.000000

# %%
tv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             912 non-null    object
#  1   Resolution        912 non-null    object
#  2   Size              912 non-null    int64
#  3   Selling Price     912 non-null    int64
#  4   Original Price    912 non-null    int64
#  5   Operating System  901 non-null    object
#  6   Rating            692 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 50.0+ KB

# %%
tv.isnull().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# dtype: int64

# %%
tv=tv.fillna(0)

# %%
tv.isnull().sum()
# Out:
# Brand               0
# Resolution          0
# Size                0
# Selling Price       0
# Original Price      0
# Operating System    0
# Rating              0
# dtype: int64

# %%
tv1.isnull().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# dtype: int64

# %%
tv2=tv1.copy()

# %%
tv1['Rating'].fillna(0,inplace=True)

# %%
tv1.isnull().sum()
# Out:
# Brand                0
# Resolution           0
# Size                 0
# Selling Price        0
# Original Price       0
# Operating System    11
# Rating               0
# dtype: int64

# %%
tv1.duplicated().sum()
# Out:
# 30

# %%
tv1.drop_duplicates(inplace=True)

# %%
tv1.duplicated().sum()
# Out:
# 0

# %%
tv1.dropna(inplace=True)

# %%
tv1
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 907    SONY     Full HD LED     43          44999           57900
# 908    SONY     Full HD LED     40          41499           51900
# 909    SONY    Ultra HD LED     65         149990          184990
# 910    SONY          HD LED     32          32900           32900
# 911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
tv1.isna().sum()
# Out:
# Brand               0
# Resolution          0
# Size                0
# Selling Price       0
# Original Price      0
# Operating System    0
# Rating              0
# dtype: int64

# %%
tv0 = tv1.copy()

# %%
tv1.reset_index(inplace=True)

# %%
tv1
# Out:
#      index    Brand     Resolution  Size   Selling Price  Original Price  \
# 0        0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1        1     TCL   QLED Ultra HD     55          52999          129990
# 2        2  realme          HD LED     32          13999           17999
# 3        3      Mi          HD LED     32          14999           19999
# 4        4  realme          HD LED     32          12999           21999
# ..     ...      ...            ...    ...            ...             ...
# 866    907    SONY     Full HD LED     43          44999           57900
# 867    908    SONY     Full HD LED     40          41499           51900
# 868    909    SONY    Ultra HD LED     65         149990          184990
# 869    910    SONY          HD LED     32          32900           32900
# 870    911    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# ...

# %%
tv1 = tv1.drop(['index'],axis=1)

# %%
tv1
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 866    SONY     Full HD LED     43          44999           57900
# 867    SONY     Full HD LED     40          41499           51900
# 868    SONY    Ultra HD LED     65         149990          184990
# 869    SONY          HD LED     32          32900           32900
# 870    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# 2            Android     4.3
# 3            Android     4.4
# ...

# %%
brand = tv1.groupby('Brand')

# %%
brand['Selling Price'].get_group('SAMSUNG').sum()
# Out:
# 14897292

# %%
brand['Selling Price'].sum()
# Out:
# Brand
# AISEN                 283700
# Acer                  269983
# Adsun                 106543
# Akai                  192732
# BPL                   138469
# Blaupunkt             355685
# Candes                 66995
# CloudWalker           290982
# Compaq                229995
# Coocaa                219982
# Croma                 254394
# DETEL                  54332
# Dektron                26896
# Dyanora                93094
# G-TEN                 135347
# HUIDI                 108994
# Haier                 659092
# Hisense               897954
# IMPEX                 374652
# Infinix                51497
# Intex                 191385
# JVC                   194978
# KODAK                 354976
# KRISONS                17597
# LG                  11182794
# Lloyd                 652882
# LumX                  149150
# MOTOROLA              575985
# MURPHY                 16799
# MarQ by Flipkart      107996
# Mi                    584954
# Micromax              671739
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=tv,x='Brand')
plt.xticks(rotation=90)
plt.show()

# %%
tv1[['Selling Price','Original Price','Rating']].corr()
# Out:
#                 Selling Price  Original Price    Rating
# Selling Price        1.000000        0.939391 -0.242372
# Original Price       0.939391        1.000000 -0.222168
# Rating              -0.242372       -0.222168  1.000000

# %%
tv_grp = tv1[['Brand','Selling Price', 'Original Price']].groupby('Brand').sum()
tv_grp.sort_values(by='Original Price' , ascending = False , inplace=True)
tv_grp
# Out:
#                   Selling Price  Original Price
# Brand
# SAMSUNG                14897292        18489265
# LG                     11182794        15805865
# SONY                    5494356         8039495
# TCL                     2144147         4031884
# Panasonic               1547077         2178030
# iFFALCON by TCL         1030454         1899819
# Vu                      1072947         1521484
# Sharp                   1197376         1253250
# PHILIPS                  573286         1074850
# Hisense                  897954         1007900
# Lloyd                    652882          999607
# Haier                    659092          989581
# Micromax                 671739          837938
# MOTOROLA                 575985          822389
# Sansui                   662805          786328
# Samsung                  729780          729780
# TOSHIBA                  505087          715906
# Mi                       584954          713981
# ...

# %%
res_grp = tv1.groupby("Resolution")

# %%
res_grp["Brand"].get_group("HD LED").unique()
# Out:
# array(['realme ', 'Mi ', 'OnePlus', 'LG ', 'Coocaa ', 'TOSHIBA',
#        'Infinix', 'Thomson', 'SONY ', 'SAMSUNG', 'KODAK ', 'MOTOROLA',
#        'Acer', 'Nokia ', 'Adsun', 'TCL ', 'T-Series', 'Micromax',
#        'Croma ', 'Candes ', 'Dyanora', 'Hisense', 'RGL ', 'PHILIPS',
#        'Panasonic', 'Sansui ', 'IMPEX ', 'Onida', 'Blaupunkt', 'Lloyd ',
#        'Power Guard', 'VG ', 'Onix ', 'HUIDI ', 'Intex ', 'LumX ',
#        'Haier ', 'BPL ', 'G-TEN ', 'Vu', 'Dektron', 'iFFALCON by TCL',
#        'CloudWalker', 'Akai ', 'DETEL ', 'KRISONS', 'Compaq ', 'AISEN  ',
#        'JVC', 'MarQ by Flipkart', 'Sharp '], dtype=object)

# %%
rating_grp = tv1.groupby(["Rating","Resolution"])

# %%
rating_grp["Resolution"].count()
# Out:
# Rating  Resolution
# 0.0     Full HD LED      37
#         HD LED           44
#         HD Plasma         1
#         QLED Ultra HD    25
#         Ultra HD LED     99
#                          ..
# 4.9     Ultra HD LED      1
# 5.0     Full HD LED       5
#         HD LED            2
#         QLED Ultra HD     2
#         Ultra HD LED      9
# Name: Resolution, Length: 73, dtype: int64

# %%
res_grp["Brand"].get_group("QLED Ultra HD").unique()
# Out:
# array(['TCL ', 'Mi ', 'MOTOROLA', 'Nokia ', 'SAMSUNG', 'iFFALCON by TCL',
#        'Vu', 'Compaq ', 'Power Guard', 'Hisense', 'Akai ', 'OnePlus',
#        'Sansui '], dtype=object)

# %%
tv1[tv1["Rating"]==5].head(10)
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 164      LG    Ultra HD LED     65         129999          229900
# 211  SAMSUNG  QLED Ultra HD     65         224999          279900
# 224   Haier     Full HD LED     42          28240           43990
# 226    SONY    Ultra HD LED     65         469999          529900
# 243      LG    Ultra HD LED     65         224999          379990
# 325      LG    Ultra HD LED     65         149999          219990
# 328  SAMSUNG  QLED Ultra HD     55         274900          274900
# 342      LG    Ultra HD LED     65         109999          209990
# 357  SAMSUNG   Ultra HD LED     55         154900          154900
# 380   Croma    Ultra HD LED     43          35990           50000
#
#     Operating System  Rating
# 164            WebOS     5.0
# 211            Tizen     5.0
# 224          Android     5.0
# 226          Android     5.0
# 243            WebOS     5.0
# 325            WebOS     5.0
# ...

# %%
tv1.loc[tv1["Rating"].idxmax()]
# Out:
# Brand                        LG
# Resolution          Ultra HD LED
# Size                          65
# Selling Price             129999
# Original Price            229900
# Operating System           WebOS
# Rating                       5.0
# Name: 164, dtype: object

# %%
tv1.describe().T
# Out:
#                 count          mean           std     min       25%      50%  \
# Size            871.0     46.303100     12.205425    17.0     39.00     46.0
# Selling Price   871.0  60347.825488  66473.367208  4849.0  20757.00  36999.0
# Original Price  871.0  83513.623421  85840.729164  6999.0  29900.00  53900.0
# Rating          871.0      3.239610      1.831858     0.0      3.15      4.2
#
#                     75%       max
# Size               55.0      85.0
# Selling Price   67990.0  499990.0
# Original Price  99990.0  549990.0
# Rating              4.4       5.0

# %%
# mean of selling price and median is different which tells us there are outlires
# mean of original price and median is different which tells us there are outliers

# %%
sns.boxplot(data=tv1, x="Original Price")
# Out:
# <Axes: xlabel='Original Price'>

# %%
sns.boxplot(data=tv1, x="Selling Price")
# Out:
# <Axes: xlabel='Selling Price'>

# %%
sns.boxplot(data=tv1 , x="Rating")
# Out:
# <Axes: xlabel='Rating'>

# %%
tv1[tv1["Rating"]==0]
# Out:
#         Brand    Resolution  Size   Selling Price  Original Price  \
# 121  T-Series        HD LED     24           9990           12990
# 151   SAMSUNG  Ultra HD LED     43          41900           49990
# 153       LG   Ultra HD LED     43          41349           57990
# 167    Croma         HD LED     24           7990           15000
# 168       LG   Ultra HD LED     55         137490          299990
# ..        ...           ...    ...            ...             ...
# 846    Sharp    Full HD LED     70         449900          449900
# 847    Sharp    Full HD LED     52         199990          199990
# 848    Sharp    Full HD LED     40         103990          103990
# 856   Sansui   Ultra HD LED     49          59990           59990
# 857   Sansui         HD LED     24          10500           14900
#
#     Operating System  Rating
# 121          Android     0.0
# 151            Tizen     0.0
# 153            WebOS     0.0
# 167          Android     0.0
# ...

# %%
tv1.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
tv1['Original Price'].max()
# Out:
# 549990

# %%
tv1[tv1['Original Price']==549990]
# Out:
#     Brand    Resolution  Size   Selling Price  Original Price  \
# 266   LG   Ultra HD LED     75         385099          549990
#
#     Operating System  Rating
# 266            WebOS     0.0

# %%
tv1['Selling Price'].max()
# Out:
# 499990

# %%
tv1[tv1['Selling Price']==499990]
# Hisense has the most selling price
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 497  Hisense  QLED Ultra HD     75         499990          499990
#
#     Operating System  Rating
# 497          Android     0.0

# %%
tv1['Rating'].max()
# Out:
# 5.0

# %%
discount = tv1[(tv1["Original Price"])>(tv1["Selling Price"])]
discount.reset_index(inplace=True)
discount
# Out:
#      index    Brand     Resolution  Size   Selling Price  Original Price  \
# 0        0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1        1     TCL   QLED Ultra HD     55          52999          129990
# 2        2  realme          HD LED     32          13999           17999
# 3        3      Mi          HD LED     32          14999           19999
# 4        4  realme          HD LED     32          12999           21999
# ..     ...      ...            ...    ...            ...             ...
# 746    864    SONY     Full HD LED     32          21223           33900
# 747    865    SONY    Ultra HD LED     49          54999          114900
# 748    866    SONY     Full HD LED     43          44999           57900
# 749    867    SONY     Full HD LED     40          41499           51900
# 750    868    SONY    Ultra HD LED     65         149990          184990
#
#     Operating System  Rating
# 0              VIDAA     4.3
# 1            Android     4.4
# ...

# %%
discount['discount%'] = (discount['Original Price']-discount["Selling Price"])/discount["Original Price"]*100
# Out:
# C:\Users\sreel\AppData\Local\Temp\ipykernel_17148\187784353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discount['discount%'] = (discount['Original Price']-discount["Selling Price"])/discount["Original Price"]*100

# %%
discount.drop(columns=['index'],inplace=True)
# Out:
# C:\Users\sreel\AppData\Local\Temp\ipykernel_17148\3485114075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discount.drop(columns=['index'],inplace=True)

# %%
discount
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 746    SONY     Full HD LED     32          21223           33900
# 747    SONY    Ultra HD LED     49          54999          114900
# 748    SONY     Full HD LED     43          44999           57900
# 749    SONY     Full HD LED     40          41499           51900
# 750    SONY    Ultra HD LED     65         149990          184990
#
#     Operating System  Rating  discount%
# 0              VIDAA     4.3  30.898345
# 1            Android     4.4  59.228402
# 2            Android     4.3  22.223457
# ...

# %%
tv1['discount%']=discount['discount%']

# %%
tv1
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA   Ultra HD LED     55          37999           54990
# 1       TCL   QLED Ultra HD     55          52999          129990
# 2    realme          HD LED     32          13999           17999
# 3        Mi          HD LED     32          14999           19999
# 4    realme          HD LED     32          12999           21999
# ..       ...            ...    ...            ...             ...
# 866    SONY     Full HD LED     43          44999           57900
# 867    SONY     Full HD LED     40          41499           51900
# 868    SONY    Ultra HD LED     65         149990          184990
# 869    SONY          HD LED     32          32900           32900
# 870    SONY     Full HD LED     43          56900           56900
#
#     Operating System  Rating  discount%
# 0              VIDAA     4.3  30.898345
# 1            Android     4.4  59.228402
# 2            Android     4.3  22.223457
# ...

# %%
dis50=tv1[tv1['discount%']>=50]

# %%
dis50['Rating'].value_counts()
# Out:
# 0.0    21
# 4.3    20
# 4.2     9
# 4.4     8
# 4.5     5
# 3.9     4
# 4.0     4
# 3.8     3
# 4.1     3
# 3.6     2
# 3.3     2
# 4.7     1
# 4.8     1
# 3.7     1
# 4.6     1
# Name: Rating, dtype: int64

# %%
dis60=tv1[tv1['discount%']>=60]

# %%
dis60
# Out:
#                Brand     Resolution  Size   Selling Price  Original Price  \
# 24           Coocaa          HD LED     32          10999           36990
# 57   iFFALCON by TCL   Ultra HD LED     55          35999          106990
# 75              TCL     Full HD LED     55          41999          109990
# 91           Coocaa     Full HD LED     42          18999           48990
# 94   iFFALCON by TCL  QLED Ultra HD     55          44999          126990
# 142  iFFALCON by TCL   Ultra HD LED     65          53999          106990
# 149            SONY     Full HD LED     43          46799           52900
# 197              Mi          HD LED     32          14999           14999
# 297          SAMSUNG   Ultra HD LED     55         241900          241900
# 399      Power Guard         HD LED     32          15499           24990
# 410              LG    Ultra HD LED     65         174999          209990
# 454             BPL    Ultra HD LED     50          42490           60000
# ...

# %%
tv1[tv1['Brand']=='TOSHIBA']
# Out:
#        Brand    Resolution  Size   Selling Price  Original Price  \
# 0    TOSHIBA  Ultra HD LED     55          37999           54990
# 19   TOSHIBA  Ultra HD LED     43          27999           39990
# 25   TOSHIBA        HD LED     32          12499           14990
# 131  TOSHIBA   Full HD LED     43          22499           26990
# 230  TOSHIBA  Ultra HD LED     50          33999           46990
# 232  TOSHIBA        HD LED     32          17499           18990
# 480  TOSHIBA  Ultra HD LED     65          63999          119999
# 519  TOSHIBA  Ultra HD LED     55          40599           50999
# 604  TOSHIBA  Ultra HD LED     43          28999           38999
# 837  TOSHIBA   Full HD LED     43          24999           31990
# 838  TOSHIBA  Ultra HD LED     65          66999           84990
# 839  TOSHIBA   Full HD LED     49          29999           51999
# 840  TOSHIBA  Ultra HD LED     65          96999          133990
#
#     Operating System  Rating  discount%
# ...

# %%
tv1.sort_values(by='Original Price',ascending=False).head(50)
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 266      LG    Ultra HD LED     75         385099          549990
# 226    SONY    Ultra HD LED     65         469999          529900
# 497  Hisense  QLED Ultra HD     75         499990          499990
# 346      LG    Ultra HD LED     65         349999          499990
# 228    SONY    Ultra HD LED     75         259999          499900
# 274  SAMSUNG  QLED Ultra HD     65         470900          470900
# 256    SONY    Ultra HD LED     65         259999          449900
# 846   Sharp     Full HD LED     70         449900          449900
# 694  SAMSUNG    Full HD LED     75         419900          419900
# 302  SAMSUNG  QLED Ultra HD     65         258999          419900
# 229      LG    Ultra HD LED     65         249999          409990
# 568     TCL   QLED Ultra HD     75         149990          399990
# 208      LG    Ultra HD LED     65         279990          399990
# ...

# %%
sns.countplot(data=tv1,x='Operating System')
# Out:
# <Axes: xlabel='Operating System', ylabel='count'>

# %%
tv1['Resolution'].value_counts(normalize=True)*100
# Out:
# Ultra HD LED     44.776119
# HD LED           24.454650
# Full HD LED      23.536165
# QLED Ultra HD     6.888634
# HD Plasma         0.344432
# Name: Resolution, dtype: float64

# %%
sns.countplot(data=tv1,x='Resolution')
# Out:
# <Axes: xlabel='Resolution', ylabel='count'>

# %%
tv1[(tv1['Rating']>4)&(tv1['Selling Price']>50000)].sort_values(by='Selling Price',ascending=False)
# Out:
#        Brand     Resolution  Size   Selling Price  Original Price  \
# 226    SONY    Ultra HD LED     65         469999          529900
# 329      LG    Ultra HD LED     55         324990          324990
# 251  SAMSUNG   Ultra HD LED     65         294900          294900
# 328  SAMSUNG  QLED Ultra HD     55         274900          274900
# 661  SAMSUNG    Full HD LED     55         267000          267000
# ..       ...            ...    ...            ...             ...
# 147  OnePlus   Ultra HD LED     55          52999           59999
# 1       TCL   QLED Ultra HD     55          52999          129990
# 504  SAMSUNG   Ultra HD LED     55          51999           72900
# 62   SAMSUNG   Ultra HD LED     50          51990           71400
# 552   Sanyo    Ultra HD LED     55          50999           76990
#
#     Operating System  Rating  discount%
# 226          Android     5.0   8.003201
# 329            WebOS     4.6  49.983328
# 251            Tizen     4.7  33.492937
# ...

# %%
brand['Selling Price'].median().sort_values(ascending=False)
# Out:
# Brand
# Sharp               127990.0
# Samsung             103995.0
# LG                   76737.0
# SAMSUNG              74490.0
# SONY                 64599.0
# Akai                 51146.0
# OnePlus              49999.0
# Sanyo                45499.0
# Panasonic            45129.0
# Weston               40990.0
# Nokia                39999.0
# TCL                  39999.0
# Hisense              39499.0
# iFFALCON by TCL      36999.0
# MOTOROLA             35999.0
# Oxygen               35990.0
# BPL                  35740.0
# PHILIPS              35729.0
# Acer                 34994.5
# Compaq               32999.0
# Onix                 32990.0
# JVC                  32494.5
# Vu                   30999.0
# Haier                30994.5
# Sansui               30490.0
# TOSHIBA              29999.0
# Onida                29399.5
# IMPEX                28690.0
# Mi                   27999.0
# Coocaa               25999.0
# AISEN                25970.0
# Lloyd                25490.0
# ...
